# %% [markdown]
# ## Script to Pull American Community Survey Census Data

# %% [markdown]
# This script utilizes the following API:
# https://pypi.org/project/CensusData/

# %%
import pandas as pd
import censusdata

# %% [markdown]
# ## Fill in options in the cell below

# %%
# set survey to pull from American Community Survey Estimates (options are 'acs1', 'acs3','acs5')
survey = 'acs1'

# years parameter for download 
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019]

file_name = 'census_data.xlsx'

# %%
# search for table ID to use in query 
censusdata.search('acs1', 2016, 'label', 'educational')
# Out:
# [('B08126_011E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('B08126_026E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Car, truck, or van - drove alone!!Educational services, and health care and social assistance'),
#  ('B08126_041E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Car, truck, or van - carpooled!!Educational services, and health care and social assistance'),
#  ('B08126_056E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Public transportation (excluding taxicab)!!Educational services, and health care and social assistance'),
#  ('B08126_071E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Walked!!Educational services, and health care and social assistance'),
#  ('B08126_086E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!Educational services, and health care and social assistance'),
#  ('B08126_101E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Worked at home!!Educational services, and health care and social assistance'),
#  ('B08526_011E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('B08526_026E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Car, truck, or van - drove alone!!Educational services, and health care and social assistance'),
#  ('B08526_041E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Car, truck, or van - carpooled!!Educational services, and health care and social assistance'),
#  ('B08526_056E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Public transportation (excluding taxicab)!!Educational services, and health care and social assistance'),
#  ('B08526_071E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Walked!!Educational services, and health care and social assistance'),
#  ('B08526_086E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Taxicab, motorcycle, bicycle, or other means!!Educational services, and health care and social assistance'),
#  ('B08526_101E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Worked at home!!Educational services, and health care and social assistance'),
#  ('B24030_092E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance'),
#  ('B24030_093E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24030_094E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24030_095E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance!!Health care'),
#  ('B24030_096E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance!!Social assistance'),
#  ('B24030_196E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance'),
#  ('B24030_197E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24030_198E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24030_199E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance!!Health care'),
#  ('B24030_200E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance!!Social assistance'),
#  ('B24031_020E',
#   'INDUSTRY BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('B24031_021E',
#   'INDUSTRY BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24031_022E',
#   'INDUSTRY BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24032_020E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Male!!Educational services, and health care and social assistance'),
#  ('B24032_021E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Male!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24032_022E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Male!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24032_047E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Female!!Educational services, and health care and social assistance'),
#  ('B24032_048E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Female!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24032_049E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Female!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24040_092E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance'),
#  ('B24040_093E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24040_094E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24040_095E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance!!Health care'),
#  ('B24040_096E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance!!Social assistance'),
#  ('B24040_196E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance'),
#  ('B24040_197E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24040_198E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24040_199E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance!!Health care'),
#  ('B24040_200E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance!!Social assistance'),
#  ('B24041_020E',
#   'INDUSTRY BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('B24041_021E',
#   'INDUSTRY BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24041_022E',
#   'INDUSTRY BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24042_020E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Male!!Educational services, and health care and social assistance'),
#  ('B24042_021E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Male!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24042_022E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Male!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24042_047E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Female!!Educational services, and health care and social assistance'),
#  ('B24042_048E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Female!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24042_049E',
#   'SEX BY INDUSTRY AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2016 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Female!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24050_020E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('B24050_021E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24050_022E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24050_047E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Management, business, science, and arts occupations!!Educational services, and health care and social assistance'),
#  ('B24050_048E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Management, business, science, and arts occupations!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24050_049E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Management, business, science, and arts occupations!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24050_074E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Service occupations!!Educational services, and health care and social assistance'),
#  ('B24050_075E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Service occupations!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24050_076E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Service occupations!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24050_101E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Sales and office occupations!!Educational services, and health care and social assistance'),
#  ('B24050_102E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Sales and office occupations!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24050_103E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Sales and office occupations!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24050_128E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Natural resources, construction, and maintenance occupations!!Educational services, and health care and social assistance'),
#  ('B24050_129E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Natural resources, construction, and maintenance occupations!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24050_130E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Natural resources, construction, and maintenance occupations!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24050_155E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Production, transportation, and material moving occupations!!Educational services, and health care and social assistance'),
#  ('B24050_156E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Production, transportation, and material moving occupations!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24050_157E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Production, transportation, and material moving occupations!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24070_020E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('B24070_021E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24070_022E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24070_047E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Employee of private company workers!!Educational services, and health care and social assistance'),
#  ('B24070_048E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Employee of private company workers!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24070_049E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Employee of private company workers!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24070_074E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own incorporated business workers!!Educational services, and health care and social assistance'),
#  ('B24070_075E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own incorporated business workers!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24070_076E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own incorporated business workers!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24070_101E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Private not-for-profit wage and salary workers!!Educational services, and health care and social assistance'),
#  ('B24070_102E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Private not-for-profit wage and salary workers!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24070_103E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Private not-for-profit wage and salary workers!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24070_128E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Local, state, and federal government workers!!Educational services, and health care and social assistance'),
#  ('B24070_129E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Local, state, and federal government workers!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24070_130E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Local, state, and federal government workers!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('B24070_155E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own not incorporated business workers and unpaid family workers!!Educational services, and health care and social assistance'),
#  ('B24070_156E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own not incorporated business workers and unpaid family workers!!Educational services, and health care and social assistance!!Educational services'),
#  ('B24070_157E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own not incorporated business workers and unpaid family workers!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('C08126_010E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('C08126_024E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Car, truck, or van - drove alone!!Educational services, and health care and social assistance'),
#  ('C08126_038E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Car, truck, or van - carpooled!!Educational services, and health care and social assistance'),
#  ('C08126_052E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Public transportation (excluding taxicab)!!Educational services, and health care and social assistance'),
#  ('C08126_066E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Taxicab, motorcycle, bicycle, walked, or other means!!Educational services, and health care and social assistance'),
#  ('C08126_080E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY',
#   'Estimate!!Total!!Worked at home!!Educational services, and health care and social assistance'),
#  ('C08526_010E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('C08526_024E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Car, truck, or van - drove alone!!Educational services, and health care and social assistance'),
#  ('C08526_038E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Car, truck, or van - carpooled!!Educational services, and health care and social assistance'),
#  ('C08526_052E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Public transportation (excluding taxicab)!!Educational services, and health care and social assistance'),
#  ('C08526_066E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Taxicab, motorcycle, bicycle, walked, or other means!!Educational services, and health care and social assistance'),
#  ('C08526_080E',
#   'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'Estimate!!Total!!Worked at home!!Educational services, and health care and social assistance'),
#  ('C24030_021E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance'),
#  ('C24030_022E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Educational services'),
#  ('C24030_023E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('C24030_048E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance'),
#  ('C24030_049E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Educational services'),
#  ('C24030_050E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('C24040_021E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance'),
#  ('C24040_022E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Educational services'),
#  ('C24040_023E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('C24040_048E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance'),
#  ('C24040_049E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Educational services'),
#  ('C24040_050E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Educational services, and health care and social assistance!!Health care and social assistance'),
#  ('C24050_011E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN  EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and health care and social assistance'),
#  ('C24050_025E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN  EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Management, business, science, and arts occupations!!Educational services, and health care and social assistance'),
#  ('C24050_039E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN  EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Service occupations!!Educational services, and health care and social assistance'),
#  ('C24050_053E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN  EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Sales and office occupations!!Educational services, and health care and social assistance'),
#  ('C24050_067E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN  EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Natural resources, construction, and maintenance occupations!!Educational services, and health care and social assistance'),
#  ('C24050_081E',
#   'INDUSTRY BY OCCUPATION FOR THE CIVILIAN  EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Production, transportation, and material moving occupations!!Educational services, and health care and social assistance'),
#  ('C24070_011E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Educational services, and  health care and social assistance'),
#  ('C24070_025E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Employee of private company workers!!Educational services, and  health care and social assistance'),
#  ('C24070_039E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own incorporated business workers!!Educational services, and  health care and social assistance'),
#  ('C24070_053E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Private not-for-profit wage and salary workers!!Educational services, and  health care and social assistance'),
#  ('C24070_067E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Local, state, and federal government workers!!Educational services, and  health care and social assistance'),
#  ('C24070_081E',
#   'INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Self-employed in own not incorporated business workers and unpaid family workers!!Educational services, and  health care and social assistance')]

# %% [markdown]
# ## Example Tables from American Community Survey 1-year data (ACS1)
# <br>
# population:
# <br>
# ('B01003_001E', 'TOTAL POPULATION', 'Estimate!!Total')
# <br>
# <br>
# race:
# <br>
# ('B02001_001E', 'RACE', 'Estimate!!Total:'),
# <br>
# ('B02001_002E', 'RACE', 'Estimate!!Total:!!White alone'),
#
# <br>
# <br>
# education:
# <br>
# 'B15003_022E':'bachelors','B15003_023E':'masters','B15003_024E':'pro_school','B15003_025E':'doctorate'
# <br>
# <br>
# median_income:
# <br>
# ('B19001_001E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN x year INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Total:'),
#
#
# ## Other sources to help you find the table you are looking for
# https://censusreporter.org/
# https://api.census.gov/data/2017/acs/acs5/groups/{table_id}.html
# <br>
# Example:
# <br>
# Searching "Median Income" in census reporter to get the idea to start looking into table B19001. We can see a full breakdown of the json structure of the Census API with this link to see what columns are available in this table:
# https://api.census.gov/data/2017/acs/acs5/groups/B19001.html

# %%
my_tables = ['B01003_001E', 'B02001_001E', 'B02001_002E','B15003_022E', 'B15003_023E','B15003_024E','B15003_025E', 'B19001_001E']

# %%
years_str = ([str(x) for x in years])
tables = {}
data = pd.DataFrame()

for year in years:
    
    # download table data from census
    data = censusdata.download(survey, year, censusdata.censusgeo([('state', '*')]), my_tables
                              )
    
    # set state name as the index column
    data = data.reset_index()
    data['state'] = data['index'].astype(str).str.split(':').str[0]
    data = data.drop(['index'], axis=1)
    data = data.set_index('state')
    
    # create column for year
    data['year'] = year
    
    #uncomment below to rename your columns with more descriptive names
    '''
    # rename table column headers
    data = data.rename(columns={'B01003_001E':'population','B19013_001E':'median_income', 'B02001_001E':'race_total','B02001_002E':'white_only',
                                'B15003_022E':'bachelors','B15003_023E':'masters','B15003_024E':'pro_school','B15003_025E':'doctorate'})
    '''

    # store data for each yeah in dictionary with key year{year} ex: 'year2019'
    tables["year{0}".format(year)] = data.copy()

# %%
data = pd.concat(tables.values())

# %%
data
# Out:
#                B01003_001E  B02001_001E  B02001_002E  B15003_022E  \
# state
# Mississippi        2991207      2991207      1764640       248488
# Missouri           6044171      6044171      5003971       685991
# Montana            1015165      1015165       904740       135518
# Nebraska           1868516      1868516      1650358       238160
# Nevada             2790136      2790136      1906864       282283
# ...                    ...          ...          ...          ...
# Washington         7614893      7614893      5651091      1204728
# West Virginia      1792147      1792147      1668004       161686
# Wisconsin          5822434      5822434      4963354       829878
# Wyoming             578759       578759       525860        73183
# Puerto Rico        3193694      3193694      2054764       443589
#
#                B15003_023E  B15003_024E  B15003_025E  B19001_001E  year
# state
# Mississippi         104166        23099        17653      1091002  2013
# Missouri            293327        63486        48201      2362853  2013
# Montana              44501        12062         7707       406288  2013
# Nebraska             81414        22745        14473       730579  2013
# Nevada               97337        27801        14679      1002571  2013
# ...                    ...          ...          ...          ...   ...
# Washington          538939       122253        89712      2932477  2019
# West Virginia        80380        15831        11809       728175  2019
# Wisconsin           307952        71262        49287      2386623  2019
# Wyoming              29454         6035         4885       233128  2019
# Puerto Rico         124314        27969        30708      1170982  2019
#
# [364 rows x 9 columns]

# %%
data = data.sort_values(by='state')

# %%
data.to_excel(file_name)
